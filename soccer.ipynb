# %%
import pandas as pd
data_frame=pd.read_csv('data.csv')
data_frame.shape # gives the total rows(-----) and coloumn(|)
# Out:
# (18207, 89)

# %%
data_frame.describe() # summary statisttics for numerical coloumn like mean max std min etc.
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data_frame.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       dtype=object)

# %%
data_frame.head(4)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# ...

# %%
data_frame.tail(4)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
# ...

# %%
data_frame.info()  # gives index ,datatype and memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
data_frame.apply(pd.Series.value_counts) #gives Unique values an count for all coloumn
# Out:
#        Unnamed: 0  ID  Name  Age  Photo  Nationality  Flag  Overall  \
# 0             1.0 NaN   NaN  NaN    NaN          NaN   NaN      NaN
# 1             1.0 NaN   NaN  NaN    NaN          NaN   NaN      NaN
# 2             1.0 NaN   NaN  NaN    NaN          NaN   NaN      NaN
# 3             1.0 NaN   NaN  NaN    NaN          NaN   NaN      NaN
# 4             1.0 NaN   NaN  NaN    NaN          NaN   NaN      NaN
# ...           ...  ..   ...  ...    ...          ...   ...      ...
# €998K         NaN NaN   NaN  NaN    NaN          NaN   NaN      NaN
# €999K         NaN NaN   NaN  NaN    NaN          NaN   NaN      NaN
# €99K          NaN NaN   NaN  NaN    NaN          NaN   NaN      NaN
# €9K           NaN NaN   NaN  NaN    NaN          NaN   NaN      NaN
# €9M           NaN NaN   NaN  NaN    NaN          NaN   NaN      NaN
#
#        Potential  Club  ...  Composure  Marking  StandingTackle  \
# 0            NaN   NaN  ...        NaN      NaN             NaN
# ...

# %%
data_frame.mean() # return the mean of all column same way we can find max ,min ,median ,std
# Out:
# Unnamed: 0                    9103.000000
# ID                          214298.338606
# Age                             25.122206
# Overall                         66.238699
# Potential                       71.307299
# Special                       1597.809908
# International Reputation         1.113222
# Weak Foot                        2.947299
# Skill Moves                      2.361308
# Jersey Number                   19.546096
# Crossing                        49.734181
# Finishing                       45.550911
# HeadingAccuracy                 52.298144
# ShortPassing                    58.686712
# Volleys                         42.909026
# Dribbling                       55.371001
# Curve                           47.170824
# FKAccuracy                      42.863153
# LongPassing                     52.711933
# BallControl                     58.369459
# Acceleration                    64.614076
# SprintSpeed                     64.726967
# ...

# %%
data_frame.corr()  # return the corellation between coloumn in a dataframe
# Out:
#                           Unnamed: 0        ID       Age   Overall  Potential  \
# Unnamed: 0                  1.000000  0.415757 -0.454846 -0.972791  -0.633395
# ID                          0.415757  1.000000 -0.739208 -0.417025   0.047074
# Age                        -0.454846 -0.739208  1.000000  0.452350  -0.253312
# Overall                    -0.972791 -0.417025  0.452350  1.000000   0.660939
# Potential                  -0.633395  0.047074 -0.253312  0.660939   1.000000
# Special                    -0.596508 -0.231352  0.236695  0.606960   0.383727
# International Reputation   -0.413322 -0.356191  0.253765  0.499491   0.372993
# Weak Foot                  -0.204026 -0.075784  0.059867  0.212015   0.162346
# Skill Moves                -0.415672 -0.056914  0.027649  0.414463   0.354290
# Jersey Number               0.213645  0.182074 -0.241156 -0.218931  -0.010474
# Crossing                   -0.390062 -0.131994  0.130545  0.394972   0.246319
# ...

# %% [markdown]
# data_frame.count() # return the number of all non null values in each Dataframe column

# %%
data_frame.count() # return the number of all non null values in each Dataframe column
# Out:
# Unnamed: 0        18207
# ID                18207
# Name              18207
# Age               18207
# Photo             18207
#                   ...
# GKHandling        18159
# GKKicking         18159
# GKPositioning     18159
# GKReflexes        18159
# Release Clause    16643
# Length: 89, dtype: int64

# %% [markdown]
# # SELECTING SINGLE DATA OR MAKING SUBSETS

# %%
data_frame[col]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-23a8876bf017> in <module>
# ----> 1 data_frame[col]
#
# NameError: name 'col' is not defined

# %% [markdown]
# # Data Cleaning

# %%
data_frame[data_frame["Age"]>40].head()
# Out:
#        Unnamed: 0      ID         Name  Age  \
# 1120         1120  156092    J. Villar   41
# 4228         4228    3665     B. Nivet   41
# 4741         4741  140029     O. Pérez   45
# 7225         7225  142998     C. Muñoz   41
# 10545       10545  140183  S. Narazaki   42
#
#                                                 Photo Nationality  \
# 1120   https://cdn.sofifa.org/players/4/19/156092.png    Paraguay
# 4228     https://cdn.sofifa.org/players/4/19/3665.png      France
# 4741   https://cdn.sofifa.org/players/4/19/140029.png      Mexico
# 7225   https://cdn.sofifa.org/players/4/19/142998.png   Argentina
# 10545  https://cdn.sofifa.org/players/4/19/140183.png       Japan
#
#                                        Flag  Overall  Potential  \
# 1120    https://cdn.sofifa.org/flags/58.png       77         77
# 4228    https://cdn.sofifa.org/flags/18.png       71         71
# 4741    https://cdn.sofifa.org/flags/83.png       71         71
# ...

# %%
df1=pd.DataFrame(data_frame,columns=['ID','Name','Wage','Value'])

df1
# Out:
#            ID                Name   Wage    Value
# 0      158023            L. Messi  €565K  €110.5M
# 1       20801   Cristiano Ronaldo  €405K     €77M
# 2      190871           Neymar Jr  €290K  €118.5M
# 3      193080              De Gea  €260K     €72M
# 4      192985        K. De Bruyne  €355K    €102M
# ...       ...                 ...    ...      ...
# 18202  238813        J. Lundstram    €1K     €60K
# 18203  243165  N. Christoffersson    €1K     €60K
# 18204  241638           B. Worman    €1K     €60K
# 18205  246268      D. Walker-Rice    €1K     €60K
# 18206  246269           G. Nugent    €1K     €60K
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0
wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage   #update column bcs it new coloumn
df1['Value']=value # same as previuos 

df1['difference']=df1['Value']-df1['Wage']

df1
# Out:
#            ID                Name      Wage        Value   difference
# 0      158023            L. Messi  565000.0  110500000.0  109935000.0
# 1       20801   Cristiano Ronaldo  405000.0   77000000.0   76595000.0
# 2      190871           Neymar Jr  290000.0  118500000.0  118210000.0
# 3      193080              De Gea  260000.0   72000000.0   71740000.0
# 4      192985        K. De Bruyne  355000.0  102000000.0  101645000.0
# ...       ...                 ...       ...          ...          ...
# 18202  238813        J. Lundstram    1000.0      60000.0      59000.0
# 18203  243165  N. Christoffersson    1000.0      60000.0      59000.0
# 18204  241638           B. Worman    1000.0      60000.0      59000.0
# 18205  246268      D. Walker-Rice    1000.0      60000.0      59000.0
# 18206  246269           G. Nugent    1000.0      60000.0      59000.0
#
# [18207 rows x 5 columns]

# %%
df1.sort_values('difference',ascending=False)
# Out:
#            ID          Name      Wage        Value   difference
# 2      190871     Neymar Jr  290000.0  118500000.0  118210000.0
# 0      158023      L. Messi  565000.0  110500000.0  109935000.0
# 4      192985  K. De Bruyne  355000.0  102000000.0  101645000.0
# 5      183277     E. Hazard  340000.0   93000000.0   92660000.0
# 15     211110     P. Dybala  205000.0   89000000.0   88795000.0
# ...       ...           ...       ...          ...          ...
# 17752  100899   S. Phillips    1000.0          0.0      -1000.0
# 12192  208927  H. Sulaimani    3000.0          0.0      -3000.0
# 3550    29552   S. Nakamura    4000.0          0.0      -4000.0
# 4228     3665      B. Nivet    5000.0          0.0      -5000.0
# 864    153260        Hilton   18000.0          0.0     -18000.0
#
# [18207 rows x 5 columns]

# %% [markdown]
# # Visulaization of Data

# %%
import seaborn as sns
sns.set()

graph=sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <AxesSubplot:xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool



p=figure(title="Soccer 2019", x_axis_label="Wage",y_axis_label="Value", plot_width=700, plot_height=700,tools=[])

show(p)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1121', ...)

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS=HoverTool(tooltips=[
    ("index","$index"),
    ("(Wage,Value)","(@Wage,@Value)"),
    ("Name",'@Name') #name of player from data
])

p=figure(title="Soccer 2019", x_axis_label="Wage",y_axis_label="Value", plot_width=700, plot_height=700,tools=[TOOLTIPS])
p.circle('Wage','Value',size=10,source=df1)
show(p)
